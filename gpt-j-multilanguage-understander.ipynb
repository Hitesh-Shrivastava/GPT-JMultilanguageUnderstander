# %%
# !pip install transformers
# !pip install datasets
# !pip install torch

# %%
from transformers import GPTJForCausalLM, Trainer, TrainingArguments
from datasets import load_dataset, DatasetDict
# Out:
# 2025-09-27 08:52:45.471334: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758963165.804641      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758963165.900691      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from transformers import GPTJForCausalLM, GPT2Tokenizer
import torch

model_name = 'EleutherAI/gpt-j-6B'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPTJForCausalLM.from_pretrained(model_name)

model.eval()
# Out:
# tokenizer_config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/357 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/930 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/24.2G [00:00<?, ?B/s]
# ...

# %%
wikitext = load_dataset("wikitext", "wikitext-103-raw-v1")
train_dataset = wikitext["train"]
# Out:
# README.md: 0.00B [00:00, ?B/s]
# wikitext-103-raw-v1/test-00000-of-00001.(…):   0%|          | 0.00/733k [00:00<?, ?B/s]
# wikitext-103-raw-v1/train-00000-of-00002(…):   0%|          | 0.00/157M [00:00<?, ?B/s]
# wikitext-103-raw-v1/train-00001-of-00002(…):   0%|          | 0.00/157M [00:00<?, ?B/s]
# wikitext-103-raw-v1/validation-00000-of-(…):   0%|          | 0.00/657k [00:00<?, ?B/s]
# ...
# Generating validation split:   0%|          | 0/3760 [00:00<?, ? examples/s]

# %%
multilang_inputs = [
    "The history of machine learning",                           
]

for input_text in multilang_inputs:
    inputs = tokenizer(input_text, return_tensors="pt").to(model.device)

    with torch.no_grad():
        outputs = model.generate(**inputs, max_length=200, do_sample=True, top_k=50)

    print(f"🔹 Input: {input_text}")
    print(f"🔸 Output: {tokenizer.decode(outputs[0], skip_special_tokens=True)}\n")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 🔹 Input: The history of machine learning
# 🔸 Output: The history of machine learning is riddled with failures. From the rise and fall of the AI winter, which ended in 1999, and the more recent AI bubble, which burst in late 2017, machine learning hasn’t really lived up to its hype. Now a report from the Wall Street Journal claims this time might be different.
#
# The report highlights the emergence of a new crop of AI startups. In particular, several firms are focused on creating machine-learning algorithms for self-driving cars. These firms have raised billions of dollars from investors, most of whom are in Asia. According to the report, venture firm Sequoia Capital has taken the lead among VCs, investing in one of these startups. VCs, however, won’t tell the Journal which company they’re investing in.
#
# ...

# %%
save_path = "/kaggle/working/GPT-JMultilanguageUnderstander"


model.save_pretrained(save_path)
tokenizer.save_pretrained(save_path)

print("Model saved to", save_path)

# %%
# !git config --global user.email "hiteshssm476@gmail.com"
# !git config --global user.name "Hitesh-Shrivastava"

# %%
# !git clone https://github.com/Hitesh-Shrivastava/GPT-JMultilanguageUnderstander.git
# Out:
# fatal: destination path 'GPT-JMultilanguageUnderstander' already exists and is not an empty directory.

# %%
import shutil

# Path to your Kaggle notebook
notebook_path = "/kaggle/working/GPT-J Multilanguage Understander.ipynb"

# Path inside your cloned repo
shutil.copy(
    notebook_path,
    "/kaggle/working/GPT-JMultilanguageUnderstander/GPT-J Multilanguage Understander.ipynb"
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_36/113679846.py in <cell line: 0>()
#       5
#       6 # Path inside your cloned repo
# ----> 7 shutil.copy(
#       8     notebook_path,
#       9     "/kaggle/working/GPT-JMultilanguageUnderstander/GPT-J Multilanguage Understander.ipynb"
#
# /usr/lib/python3.11/shutil.py in copy(src, dst, follow_symlinks)
#     429     if os.path.isdir(dst):
#     430         dst = os.path.join(dst, os.path.basename(src))
# --> 431     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     432     copymode(src, dst, follow_symlinks=follow_symlinks)
#     433     return dst
#
# /usr/lib/python3.11/shutil.py in copyfile(src, dst, follow_symlinks)
#     254         os.symlink(os.readlink(src), dst)
#     255     else:
# --> 256         with open(src, 'rb') as fsrc:
#     257             try:
# ...
